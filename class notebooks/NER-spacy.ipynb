# %%
# !pip install --user pip setuptools wheel
# !pip install --user spacy
python -m spacy download en_core_web_sm

# %%
import spacy 
import spacy.displacy as displacy
import pandas as pd

# %%
nlp = spacy.load('en_core_web_sm')

# %%
text = """
Facebook is an American online social media and social networking service owned by Meta Platforms. Founded in 2004 by Mark Zuckerberg with fellow Harvard College students and roommates Eduardo Saverin, Andrew McCollum, Dustin Moskovitz, and Chris Hughes, its name comes from the face book directories often given to American university students. Membership was initially limited to Harvard students, gradually expanding to other North American universities and, since 2006, anyone over 13 years old. As of 2020, Facebook claimed 2.8 billion monthly active users,[2] and ranked seventh in global internet usage.[7] It was the most downloaded mobile app of the 2010s.
"""

# %%
doc = nlp(text)
print(doc)
# Out:
# Facebook is an American online social media and social networking service owned by Meta Platforms. Founded in 2004 by Mark Zuckerberg with fellow Harvard College students and roommates Eduardo Saverin, Andrew McCollum, Dustin Moskovitz, and Chris Hughes, its name comes from the face book directories often given to American university students. Membership was initially limited to Harvard students, gradually expanding to other North American universities and, since 2006, anyone over 13 years old. As of 2020, Facebook claimed 2.8 billion monthly active users,[2] and ranked seventh in global internet usage.[7] It was the most downloaded mobile app of the 2010s.

# %%
for token in doc:
  print(token.text, token.pos_, token.tag_, token.dep_, token.lemma_, token.is_stop)
# Out:
#  SPACE _SP
#  False
# Facebook PROPN NNP nsubj Facebook False
# is AUX VBZ ROOT be True
# an DET DT det an True
# American ADJ JJ amod american False
# online ADJ JJ amod online False
# social ADJ JJ amod social False
# media NOUN NNS attr medium False
# and CCONJ CC cc and True
# social ADJ JJ amod social False
# networking NOUN NN compound networking False
# service NOUN NN conj service False
# owned VERB VBN acl own False
# by ADP IN agent by True
# Meta PROPN NNP compound Meta False
# Platforms PROPN NNPS pobj Platforms False
# . PUNCT . punct . False
# Founded VERB VBN advcl found False
# in ADP IN prep in True
# 2004 NUM CD pobj 2004 False
# by ADP IN agent by True
# Mark PROPN NNP compound Mark False
# Zuckerberg PROPN NNP pobj Zuckerberg False
# with ADP IN prep with True
# fellow ADJ JJ compound fellow False
# Harvard PROPN NNP compound Harvard False
# College PROPN NNP compound College False
# students NOUN NNS pobj student False
# and CCONJ CC cc and True
# roommates VERB VBZ conj roommate False
# Eduardo PROPN NNP compound Eduardo False
# Saverin PROPN NNP dobj Saverin False
# , PUNCT , punct , False
# Andrew PROPN NNP compound Andrew False
# McCollum PROPN NNP conj McCollum False
# , PUNCT , punct , False
# Dustin PROPN NNP compound Dustin False
# Moskovitz PROPN NNP conj Moskovitz False
# , PUNCT , punct , False
# and CCONJ CC cc and True
# Chris PROPN NNP compound Chris False
# Hughes PROPN NNP conj Hughes False
# , PUNCT , punct , False
# its DET PRP$ poss -PRON- True
# name NOUN NN nsubj name True
# comes VERB VBZ ROOT come False
# from ADP IN prep from True
# the DET DT det the True
# face NOUN NN compound face False
# book NOUN NN compound book False
# directories NOUN NNS pobj directory False
# often ADV RB advmod often True
# given VERB VBN acl give False
# to ADP IN dative to True
# American ADJ JJ amod american False
# university NOUN NN compound university False
# students NOUN NNS pobj student False
# . PUNCT . punct . False
# Membership NOUN NN nsubjpass membership False
# was AUX VBD auxpass be True
# initially ADV RB advmod initially False
# limited VERB VBN ROOT limit False
# to ADP IN prep to True
# Harvard PROPN NNP compound Harvard False
# students NOUN NNS pobj student False
# , PUNCT , punct , False
# gradually ADV RB advmod gradually False
# expanding VERB VBG advcl expand False
# to ADP IN prep to True
# other ADJ JJ amod other True
# North ADJ JJ amod north False
# American ADJ JJ amod american False
# universities NOUN NNS pobj university False
# and CCONJ CC cc and True
# , PUNCT , punct , False
# since SCONJ IN prep since True
# 2006 NUM CD pobj 2006 False
# , PUNCT , punct , False
# anyone PRON NN conj anyone True
# over ADP IN quantmod over True
# 13 NUM CD nummod 13 False
# years NOUN NNS npadvmod year False
# old ADJ JJ amod old False
# . PUNCT . punct . False
# As SCONJ IN prep as True
# of ADP IN prep of True
# 2020 NUM CD pobj 2020 False
# , PUNCT , punct , False
# Facebook PROPN NNP nsubj Facebook False
# claimed VERB VBD ROOT claim False
# 2.8 NUM CD compound 2.8 False
# billion NUM CD nummod billion False
# monthly ADJ JJ advmod monthly False
# active ADJ JJ ccomp active False
# users,[2 PROPN NNP punct users,[2 False
# ] PUNCT -RRB- punct ] False
# and CCONJ CC cc and True
# ranked VERB VBD conj rank False
# seventh ADJ JJ advmod seventh False
# in ADP IN prep in True
# global ADJ JJ amod global False
# internet NOUN NN compound internet False
# usage.[7 PROPN NNP pobj usage.[7 False
# ] PUNCT -RRB- punct ] False
# It PRON PRP nsubj -PRON- True
# was AUX VBD ROOT be True
# the DET DT det the True
# most ADV RBS advmod most True
# downloaded ADJ JJ amod downloaded False
# mobile ADJ JJ amod mobile False
# app NOUN NN attr app False
# of ADP IN prep of True
# the DET DT det the True
# 2010s NUM CD pobj 2010s False
# . PUNCT . punct . False
#
#  SPACE _SP
#  False

# %%
text_details = pd.DataFrame([(token.text, token.pos_, token.tag_, token.dep_, token.lemma_, token.is_stop) for token in doc], 
                            columns = ['Text', 'Pos', 'tag', 'dep', 'lemm', 'stop_bool'])

# %%
text_details
# Out:
#          Text    Pos  tag    dep      lemm  stop_bool
# 0          \n  SPACE  _SP               \n      False
# 1    Facebook  PROPN  NNP  nsubj  Facebook      False
# 2          is    AUX  VBZ   ROOT        be       True
# 3          an    DET   DT    det        an       True
# 4    American    ADJ   JJ   amod  american      False
# ..        ...    ...  ...    ...       ...        ...
# 111        of    ADP   IN   prep        of       True
# 112       the    DET   DT    det       the       True
# 113     2010s    NUM   CD   pobj     2010s      False
# 114         .  PUNCT    .  punct         .      False
# 115        \n  SPACE  _SP               \n      False
#
# [116 rows x 6 columns]

# %%
entity_details = pd.DataFrame([(ent.text, ent.start_char, ent.end_char, ent.label_) for ent in doc.ents] , 
                              columns = ['Text', 'Start', 'end', 'label'])

# %%
entity_details
# Out:
#                 Text  Start  end     label
# 0           American     16   24      NORP
# 1     Meta Platforms     84   98       ORG
# 2               2004    111  115      DATE
# 3    Mark Zuckerberg    119  134    PERSON
# 4    Harvard College    147  162       ORG
# 5    Eduardo Saverin    186  201    PERSON
# 6    Andrew McCollum    203  218    PERSON
# 7   Dustin Moskovitz    220  236    PERSON
# 8       Chris Hughes    242  254    PERSON
# 9           American    317  325      NORP
# 10           Harvard    383  390       ORG
# 11    North American    430  444      NORP
# 12              2006    469  473      DATE
# 13      13 years old    487  499      DATE
# 14              2020    507  511      DATE
# 15          Facebook    513  521       ORG
# 16       2.8 billion    530  541  CARDINAL
# 17           monthly    542  549      DATE
# 18          users,[2    557  565       ORG
# 19           seventh    578  585   ORDINAL
# 20         the 2010s    656  665      DATE

# %%
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="38a314834266406699075143ec4addca-0" class="displacy" width="17900" height="1099.5" direction="ltr" style="max-width: none; height: 1099.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Facebook</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">American</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">online</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">social</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">media</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">social</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">networking</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">service</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">owned</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">Meta</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">Platforms.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Founded</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">2004</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">Mark</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">Zuckerberg</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">fellow</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">Harvard</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">College</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">students</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">roommates</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">Eduardo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">Saverin,</t

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"></br>Facebook is an
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  online social media and social networking service owned by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Meta Platforms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Founded in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2004
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mark Zuckerberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  with fellow
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Harvard College
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  students and roommates
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Eduardo Saverin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Andrew McCollum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dustin Moskovitz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chris Hughes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , its name comes from the face book directories often given to
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  university students. Membership was initially limited to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Harvard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  students, gradually expanding to other
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     North American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  universities and, since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2006
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , anyone over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13 years old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . As of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Facebook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  claimed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2.8 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monthly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  active
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     users,[2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ] and ranked
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seventh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  in global internet usage.[7] It was the most downloaded mobile app of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 2010s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# </div></span>

# %%
text = """
The COVID-19 pandemic in India is a part of the worldwide pandemic of coronavirus disease 2019 (COVID-19) caused by severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2). As of 27 September 2021, according to official figures, India has the second-highest number of confirmed cases in the world (after the United States of America) with 33,678,786 reported cases of COVID-19 infection and the third-highest number of COVID-19 deaths (after the United States and Brazil) at 482,017[4] deaths.[6][7][8] However these figures exhibit severe under-reporting.
"""

# %%
displacy.render(nlp(text), style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"></br>The COVID-19 pandemic in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is a part of the worldwide pandemic of coronavirus disease
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (COVID-19) caused by severe acute respiratory syndrome coronavirus
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (SARS-CoV-2). As of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     27
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     September 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , according to official figures,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# -highest number of confirmed cases in the world (after
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States of America
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ) with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     33,678,786
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  reported cases of COVID-19 infection and the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# -highest number of COVID-19 deaths (after
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brazil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ) at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     482,017[4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ] deaths.[6][7][8] However these figures exhibit severe under-reporting.
# </div></span>

# %%
train_dataset = [
         ("Money transfer from my savings account is not working", {"entities": [(0, 14, "ACTIVITY"), (23, 38, 'PRODUCT')]}),
         ("I want to check balance in my savings account", {"entities": [(10, 15, "ACTIVITY"), (30, 45, 'PRODUCT')]}),
         ("I suspect a fraud in my credit card account", {"entities": [(12, 17, "ACTIVITY"), (24, 35, 'PRODUCT')]}),
         ("I am here for opening a new savings account", {"entities": [(14, 21, "ACTIVITY"), (28, 43, 'PRODUCT')]}),
         ("Your mortgage is in delinquent status", {"entities": [(20, 30, "ACTIVITY"), (5, 13, 'PRODUCT')]}),
         ("Your credit card is in past due status", {"entities": [(30, 41, "ACTIVITY"), (5, 16, 'PRODUCT')]}),
         ("My loan account is still not approved and funded", {"entities": [(25, 37, "ACTIVITY"), (3, 15, 'PRODUCT'), (42, 48, "ACTIVITY")]}),
         ("How do I open a new loan account", {"entities": [(9, 13, "ACTIVITY"), (20, 32, 'PRODUCT')]}),
         ("What are the charges on Investment account", {"entities": [(13, 20, "ACTIVITY"), (24, 42, 'PRODUCT')]}),
         ("Can you explain late charges on my credit card", {"entities": [(16, 28, "ACTIVITY"), (35, 49, 'PRODUCT')]}),
         ("I want to open a new loan account", {"entities": [(10, 14, "ACTIVITY"), (21, 33, 'PRODUCT')]}),
         ("Can you help updating payment on my credit card", {"entities": [(22, 29, "ACTIVITY"), (36, 47, 'PRODUCT')]}),
         ("When is the payment due date on my card", {"entities": [(12, 19, "ACTIVITY"), (35, 39, 'PRODUCT')]})
        ]

# %%
nlp.pipe_names
# Out:
# ['tagger', 'parser', 'ner']

# %%
ner = nlp.get_pipe('ner')

# %%
for _, annotations in train_dataset:
  print(annotations)
  for ent in annotations.get('entities'):
    ner.add_label(ent[2])
# Out:
# {'entities': [(0, 14, 'ACTIVITY'), (23, 38, 'PRODUCT')]}
# {'entities': [(10, 15, 'ACTIVITY'), (30, 45, 'PRODUCT')]}
# {'entities': [(12, 17, 'ACTIVITY'), (24, 35, 'PRODUCT')]}
# {'entities': [(14, 21, 'ACTIVITY'), (28, 43, 'PRODUCT')]}
# {'entities': [(20, 30, 'ACTIVITY'), (5, 13, 'PRODUCT')]}
# {'entities': [(30, 41, 'ACTIVITY'), (5, 16, 'PRODUCT')]}
# {'entities': [(25, 37, 'ACTIVITY'), (3, 15, 'PRODUCT'), (42, 48, 'ACTIVITY')]}
# {'entities': [(9, 13, 'ACTIVITY'), (20, 32, 'PRODUCT')]}
# {'entities': [(13, 20, 'ACTIVITY'), (24, 42, 'PRODUCT')]}
# {'entities': [(16, 28, 'ACTIVITY'), (35, 49, 'PRODUCT')]}
# {'entities': [(10, 14, 'ACTIVITY'), (21, 33, 'PRODUCT')]}
# {'entities': [(22, 29, 'ACTIVITY'), (36, 47, 'PRODUCT')]}
# {'entities': [(12, 19, 'ACTIVITY'), (35, 39, 'PRODUCT')]}

# %%
import random
import numpy as np
from spacy.util import minibatch, compounding

# %%
disable_pipe = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*disable_pipe):
  optimizer = nlp.resume_training()
  for iteration in range(0, 100):
    random.shuffle(train_dataset)
    losses = {}
    for batch in spacy.util.minibatch(train_dataset, size=compounding(1,16, 1.001)):
      for text, annotations in batch:
        nlp.update([text], [annotations], drop=0.5, losses=losses, sgd= optimizer)
        print("losses {}".format(losses))
# Out:
# losses {'ner': 8.88503921125422}
# losses {'ner': 20.891683002177544}
# losses {'ner': 30.18812134952615}
# losses {'ner': 38.80134700748469}
# losses {'ner': 50.09378820814187}
# losses {'ner': 60.90382737078137}
# losses {'ner': 70.30730529286332}
# losses {'ner': 81.06249503774764}
# losses {'ner': 87.46021834966409}
# losses {'ner': 96.24490115997064}
# losses {'ner': 104.92089327235193}
# losses {'ner': 110.31069802621933}
# losses {'ner': 120.95240508894905}
# losses {'ner': 11.232492223381996}
# losses {'ner': 21.15143851423636}
# losses {'ner': 27.06145025690298}
# losses {'ner': 38.24009658343433}
# losses {'ner': 47.28686550540018}
# losses {'ner': 51.43353313015117}
# losses {'ner': 58.22165807461291}
# losses {'ner': 64.18456329693012}
# losses {'ner': 69.75351712022834}
# losses {'ner': 78.27102706248647}
# losses {'ner': 87.8504364783348}
# losses {'ner': 31.453260250389576}
# losses {'ner': 38.089329585433006}
# losses {'ner': 42.62181586585939}
# losses {'ner': 51.29270443879068}
# losses {'ner': 56.23686002660543}
# losses {'ner': 63.01389375794679}
# losses {'ner': 69.82678121794015}
# losses {'ner': 78.61820847261697}
# losses {'ner': 84.4697796786204}
# losses {'ner': 91.33709114138037}
# losses {'ner': 8.526828587055206}
# losses {'ner': 13.976340521126986}
# losses {'ner': 19.915354937314987}
# losses {'ner': 28.88973891735077}
# losses {'ner': 38.02587769180536}
# losses {'ner': 46.001769956201315}
# losses {'ner': 53.08457624539733}
# losses {'ner': 58.75388723285869}
# losses {'ner': 65.45813433500007}
# losses {'ner': 71.33899724530056}
# losses {'ner': 79.36496282415465}
# losses {'ner': 86.98004191415384}
# losses {'ner': 92.6843301099725}
# losses {'ner': 8.792188435792923}
# losses {'ner': 14.973945900797844}
# losses {'ner': 21.724895521998405}
# losses {'ner': 29.24546404182911}
# losses {'ner': 36.32824882864952}
# losses {'ner': 41.38210390508175}
# losses {'ner': 48.238194569945335}
# losses {'ner': 56.52594315260649}
# losses {'ner': 61.039440461900085}
# losses {'ner': 66.02397558977827}
# losses {'ner': 72.75901421299204}
# losses {'ner': 76.75253818882629}
# losses {'ner': 83.46098811505362}
# losses {'ner': 5.273583302274346}
# losses {'ner': 13.20011674799025}
# losses {'ner': 19.725187057629228}
# losses {'ner': 28.01595511683263}
# losses {'ner': 36.29994269856252}
# losses {'ner': 42.81030535348691}
# losses {'ner': 51.13794583291747}
# losses {'ner': 60.67782014817931}
# losses {'ner': 66.42413963587023}
# losses {'ner': 72.14553488255478}
# losses {'ner': 77.02460842364235}
# losses {'ner': 85.31809382670326}
# losses {'ner': 95.34130792849464}
# losses {'ner': 4.513675265945494}
# losses {'ner': 8.339796434156597}
# losses {'ner': 14.917170716449618}
# losses {'ner': 19.92000484187156}
# losses {'ner': 27.37126644421369}
# losses {'ner': 34.529841472394764}
# losses {'ner': 40.33963553607464}
# losses {'ner': 46.32962095737457}
# losses {'ner': 53.95918805524707}
# losses {'ner': 61.13507081195712}
# losses {'ner': 66.47202671319246}
# losses {'ner': 72.79314313983195}
# losses {'ner': 82.87543215011829}
# losses {'ner': 5.119246308318907}
# losses {'ner': 11.639803995005423}
# losses {'ner': 16.848404560796553}
# losses {'ner': 23.072229906310895}
# losses {'ner': 31.46117596593649}
# losses {'ner': 40.36421920624525}
# losses {'ner': 50.47821261254103}
# losses {'ner': 56.37952223685534}
# losses {'ner': 65.52965382006914}
# losses {'ner': 68.83021265765063}
# losses {'ner': 73.99739103871042}
# losses {'ner': 80.07293570753762}
# losses {'ner': 87.06793206547962}
# losses {'ner': 6.113383367657661}
# losses {'ner': 10.701090648770332}
# losses {'ner': 16.75360170006752}
# losses {'ner': 22.99605038651498}
# losses {'ner': 28.530288445588667}
# losses {'ner': 34.08541155868443}
# losses {'ner': 40.332280284084845}
# losses {'ner': 47.024478381790686}
# losses {'ner': 54.05291158548789}
# losses {'ner': 58.134110764891375}
# losses {'ner': 67.55354541848646}
# losses {'ner': 71.50983536365675}
# losses {'ner': 55.922815446334425}
# losses {'ner': 63.57135835714871}
# losses {'ner': 69.81363622337813}
# losses {'ner': 74.02818926429609}
# losses {'ner': 81.46263246244052}
# losses {'ner': 7.388536483049393}
# losses {'ner': 16.96507915854454}
# losses {'ner': 24.043308466672897}
# losses {'ner': 30.80391055883956}
# losses {'ner': 40.34356752576423}
# losses {'ner': 46.21599057855201}
# losses {'ner': 50.80741715969634}
# losses {'ner': 58.45121709795785}
# losses {'ner': 66.51915697546792}
# losses {'ner': 72.79202596636605}
# losses {'ner': 80.6580190488894}
# losses {'ner': 84.90422506330651}
# losses {'ner': 92.32694686649484}
# losses {'ner': 7.317753352224827}
# losses {'ner': 14.044275987136643}
# losses {'ner': 20.824845847688266}
# losses {'ner': 27.266028918224038}
# losses {'ner': 31.59142828536278}
# losses {'ner': 40.32038051438576}
# losses {'ner': 45.829867495122016}
# losses {'ner': 52.23004089099413}
# losses {'ner': 56.91053010564961}
# losses {'ner': 64.75644094538607}
# losses {'ner': 70.84563250508823}
# losses {'ner': 78.19055582252064}
# losses {'ner': 83.72410018411198}
# losses {'ner': 5.872388872176089}
# losses {'ner': 12.166370458526217}
# losses {'ner': 15.799818083269201}
# losses {'ner': 19.734805068557762}
# losses {'ner': 24.877587577884697}
# losses {'ner': 32.66336461026003}
# losses {'ner': 38.27588086630931}
# losses {'ner': 43.99421351831188}
# losses {'ner': 50.8573075217173}
# losses {'ner': 58.54850215101396}
# losses {'ner': 66.43760781371748}
# losses {'ner': 74.97529584923541}
# losses {'ner': 82.11391387888943}
# losses {'ner': 6.024872397072613}
# losses {'ner': 10.325588864739984}
# losses {'ner': 15.892909635203978}
# losses {'ner': 20.8438303601979}
# losses {'ner': 29.207418484711525}
# losses {'ner': 32.68599304566669}
# losses {'ner': 40.3354411647706}
# losses {'ner': 46.49937196609608}
# losses {'ner': 50.94032380876706}
# losses {'ner': 56.856876788964655}
# losses {'ner': 62.36297332747017}
# losses {'ner': 70.79558431608712}
# losses {'ner': 74.97890402046141}

# %%
for text, _ in train_dataset:
  doc = nlp(text)
  print("entities", [(i.text, i.label_) for i in doc.ents])
# Out:
# entities [('loan account', 'PRODUCT'), ('funded', 'ACTIVITY')]
# entities [('open', 'ACTIVITY'), ('loan account', 'PRODUCT')]
# entities [('credit card', 'PRODUCT')]
# entities [('savings account', 'PRODUCT')]
# entities [('credit card', 'PRODUCT')]
# entities [('mortgage', 'PRODUCT'), ('delinquent', 'ACTIVITY')]
# entities [('Investment account', 'PRODUCT')]
# entities [('savings account', 'PRODUCT')]
# entities [('credit card', 'PRODUCT')]
# entities [('open', 'ACTIVITY'), ('loan account', 'PRODUCT')]
# entities []
# entities [('Money transfer', 'ACTIVITY'), ('savings account', 'PRODUCT')]
# entities [('credit card', 'PRODUCT')]

# %%
from spacy import displacy
doc = nlp("I need to apply for credit card")
displacy.render(nlp(doc.text), style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I need to apply for
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     credit card
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# </div></span>

# %%
from spacy import displacy
doc = nlp("I want to open a current account for my business")
displacy.render(nlp(doc.text), style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I want to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     open
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTIVITY</span>
# </mark>
#  a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     current
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTIVITY</span>
# </mark>
#  account for my business</div></span>

# %%
from spacy import displacy
doc = nlp("I want to open a demat account for my business")
displacy.render(nlp(doc.text), style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I want to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     open
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTIVITY</span>
# </mark>
#  a demat account for my business</div></span>
